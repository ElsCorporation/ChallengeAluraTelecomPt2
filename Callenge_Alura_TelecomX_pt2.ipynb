# %% [markdown]
# <a href="https://colab.research.google.com/github/ElsCorporation/ChallengeAluraTelecomPt2/blob/main/Callenge_Alura_TelecomX_pt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Extração do Arquivo Tratado

# %%
url = 'https://raw.githubusercontent.com/ElsCorporation/ChallengeAluraTelecomPt2/refs/heads/main/dados_telecom_x.csv'
dados = pd.read_csv(url)
dados.head()
# Out:
#    cliente_ID Churn cliente_genero  cliente_senior  cliente_parceiro  \
# 0  0002-ORFBO    No       Feminino               0                 1
# 1  0003-MKNFE    No      Masculino               0                 0
# 2  0004-TLHLJ   Yes      Masculino               0                 0
# 3  0011-IGKFF   Yes      Masculino               1                 1
# 4  0013-EXCHZ   Yes       Feminino               1                 1
#
#    cliente_dependentes  cliente_tenure  telefone_servico  \
# 0                    1               9                 1
# 1                    0               9                 1
# 2                    0               4                 1
# 3                    0              13                 1
# 4                    0               3                 1
#
#   telefone_multiplas_linhas internet_servico  ...  \
# 0                         0              DSL  ...
# 1                         1              DSL  ...
# 2                         0      Fiber optic  ...
# 3                         0      Fiber optic  ...
# 4                         0      Fiber optic  ...
#
#   internet_protecao_dispositivo internet_suporte_tecnico  \
# 0                             0                        1
# 1                             0                        0
# 2                             1                        0
# 3                             1                        0
# 4                             0                        1
#
#   internet_streaming_tv internet_streaming_filmes  conta_contrato  \
# 0                     1                         0        One year
# 1                     0                         1  Month-to-month
# 2                     0                         0  Month-to-month
# 3                     1                         1  Month-to-month
# 4                     1                         0  Month-to-month
#
#   conta_fatura_online conta_metodo_pagamento  conta_mensal conta_total  \
# 0                   1           Mailed check          65.6      593.30
# 1                   0           Mailed check          59.9      542.40
# 2                   1       Electronic check          73.9      280.85
# 3                   1       Electronic check          98.0     1237.85
# 4                   1           Mailed check          83.9      267.40
#
#    Contas_Diarias
# 0            2.20
# 1            2.01
# 2            2.34
# 3            3.17
# 4            2.97
#
# [5 rows x 22 columns]

# %% [markdown]
# # Remoção de Colunas Irrelevantes
#
# ---

# %%
dados.columns
# Out:
# Index(['cliente_ID', 'Churn', 'cliente_genero', 'cliente_senior',
#        'cliente_parceiro', 'cliente_dependentes', 'cliente_tenure',
#        'telefone_servico', 'telefone_multiplas_linhas', 'internet_servico',
#        'internet_seguranca_online', 'internet_backup_online',
#        'internet_protecao_dispositivo', 'internet_suporte_tecnico',
#        'internet_streaming_tv', 'internet_streaming_filmes', 'conta_contrato',
#        'conta_fatura_online', 'conta_metodo_pagamento', 'conta_mensal',
#        'conta_total', 'Contas_Diarias'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cliente_ID                     7043 non-null   object
#  1   Churn                          7043 non-null   object
#  2   cliente_genero                 7043 non-null   object
#  3   cliente_senior                 7043 non-null   int64
#  4   cliente_parceiro               7043 non-null   int64
#  5   cliente_dependentes            7043 non-null   int64
#  6   cliente_tenure                 7043 non-null   int64
#  7   telefone_servico               7043 non-null   int64
#  8   telefone_multiplas_linhas      7043 non-null   object
#  9   internet_servico               7043 non-null   object
#  10  internet_seguranca_online      7043 non-null   object
#  11  internet_backup_online         7043 non-null   object
#  12  internet_protecao_dispositivo  7043 non-null   object
#  13  internet_suporte_tecnico       7043 non-null   object
#  14  internet_streaming_tv          7043 non-null   object
#  15  internet_streaming_filmes      7043 non-null   object
#  16  conta_contrato                 7043 non-null   object
#  17  conta_fatura_online            7043 non-null   int64
#  18  conta_metodo_pagamento         7043 non-null   object
#  19  conta_mensal                   7043 non-null   float64
#  20  conta_total                    7032 non-null   float64
#  21  Contas_Diarias                 7032 non-null   float64
# dtypes: float64(3), int64(6), object(13)
# memory usage: 1.2+ MB

# %%
dados['internet_servico'].nunique()
# Out:
# 3

# %%
colunas_remocao = {
    'cliente_ID',
    'cliente_genero',
    'telefone_multiplas_linhas',
    'internet_streaming_tv',
    'internet_streaming_filmes',
    'conta_mensal',
    'Contas_Diarias'
}

# %%
dados_colunas_removidas = dados.drop(columns=colunas_remocao, axis=1)
dados_colunas_removidas.head()
# Out:
#   Churn  cliente_senior  cliente_parceiro  cliente_dependentes  \
# 0    No               0                 1                    1
# 1    No               0                 0                    0
# 2   Yes               0                 0                    0
# 3   Yes               1                 1                    0
# 4   Yes               1                 1                    0
#
#    cliente_tenure  telefone_servico internet_servico  \
# 0               9                 1              DSL
# 1               9                 1              DSL
# 2               4                 1      Fiber optic
# 3              13                 1      Fiber optic
# 4               3                 1      Fiber optic
#
#   internet_seguranca_online internet_backup_online  \
# 0                         0                      1
# 1                         0                      0
# 2                         0                      0
# 3                         0                      1
# 4                         0                      0
#
#   internet_protecao_dispositivo internet_suporte_tecnico  conta_contrato  \
# 0                             0                        1        One year
# 1                             0                        0  Month-to-month
# 2                             1                        0  Month-to-month
# 3                             1                        0  Month-to-month
# 4                             0                        1  Month-to-month
#
#    conta_fatura_online conta_metodo_pagamento  conta_total
# 0                    1           Mailed check       593.30
# 1                    0           Mailed check       542.40
# 2                    1       Electronic check       280.85
# 3                    1       Electronic check      1237.85
# 4                    1           Mailed check       267.40
